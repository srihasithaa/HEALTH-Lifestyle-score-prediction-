# %% [markdown]
# Install & Imports

# %%
# !pip install scikit-fuzzy --quiet

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import skfuzzy as fuzz
from skfuzzy import control as ctrl

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

pd.set_option("display.max_columns", None)

# %% [markdown]
# Load Dataset

# %%
# If Excel
df = pd.read_excel("/content/healthy_lifestyle_dataset.xlsx")

print("Shape:", df.shape)
display(df.head())
print(df.columns)
# Out:
# Shape: (3000, 22)
#    Age  Sleep_Duration_Hours     Meal_Type  Height_cm  Weight_kg   BMI  \
# 0   56                   8.3  High Protein      164.3       70.6  26.2
# 1   69                   5.8    Rice-based      165.3       80.4  29.4
# 2   46                   8.8  High Protein      163.1       91.1  34.2
# 3   32                   6.8    Roti-based      177.1       56.6  18.0
# 4   60                   8.3     Fast Food      152.6       80.9  34.7
#
#   Bilirubin_Issue Gastric_Problem  Dinner_to_Bed_Gap_Hours  \
# 0              No             Yes                      2.6
# 1              No             Yes                      3.3
# 2              No             Yes                      1.0
# 3             Yes             Yes                      4.2
# 4              No             Yes                      3.0
#
#    Physical_Activity_Min_Per_Day  Water_Intake_Liters  Stress_Level_1to5  \
# 0                            112                  1.9                  5
# 1                             21                  1.6                  4
# 2                             19                  2.4                  5
# 3                             96                  3.0                  4
# 4                              4                  2.2                  4
#
#    Screen_Time_Hours Smoking_Status Alcohol_Intake_Frequency  \
# 0                5.4        Regular                   Weekly
# 1                3.0     Occasional                   Weekly
# 2                5.1     Non-smoker                  Monthly
# 3                6.2     Occasional                  Monthly
# 4                6.9     Occasional                      NaN
#
#    Chronic_Disease_Flag  Work_Hours_Per_Day  Step_Count_Per_Day  \
# 0                     1                10.2               11073
# 1                     1                 8.6                3697
# 2                     1                 9.1               13841
# 3                     1                 8.6               15236
# 4                     0                 6.5                1952
#
#    Fruit_Veg_Servings_Per_Day  Coffee_Cups_Per_Day  \
# 0                           5                    3
# 1                           4                    2
# 2                           3                    1
# 3                           1                    4
# 4                           1                    2
#
#    Processed_Food_Frequency_Per_Week  Lifestyle_Score
# 0                                  5             18.2
# 1                                  1              4.9
# 2                                  6              0.5
# 3                                  6             18.9
# 4                                  1              0.0
# Index(['Age', 'Sleep_Duration_Hours', 'Meal_Type', 'Height_cm', 'Weight_kg',
#        'BMI', 'Bilirubin_Issue', 'Gastric_Problem', 'Dinner_to_Bed_Gap_Hours',
#        'Physical_Activity_Min_Per_Day', 'Water_Intake_Liters',
#        'Stress_Level_1to5', 'Screen_Time_Hours', 'Smoking_Status',
#        'Alcohol_Intake_Frequency', 'Chronic_Disease_Flag',
#        'Work_Hours_Per_Day', 'Step_Count_Per_Day',
#        'Fruit_Veg_Servings_Per_Day', 'Coffee_Cups_Per_Day',
#        'Processed_Food_Frequency_Per_Week', 'Lifestyle_Score'],
#       dtype='object')

# %% [markdown]
# EDA

# %%
print(df.info())
display(df.describe())

plt.figure(figsize=(6,4))
sns.histplot(df["Lifestyle_Score"], kde=True)
plt.title("Distribution of Lifestyle Score")
plt.xlabel("Lifestyle Score (0–100)")
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 22 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age                                3000 non-null   int64
#  1   Sleep_Duration_Hours               3000 non-null   float64
#  2   Meal_Type                          3000 non-null   object
#  3   Height_cm                          3000 non-null   float64
#  4   Weight_kg                          3000 non-null   float64
#  5   BMI                                3000 non-null   float64
#  6   Bilirubin_Issue                    3000 non-null   object
#  7   Gastric_Problem                    3000 non-null   object
#  8   Dinner_to_Bed_Gap_Hours            3000 non-null   float64
#  9   Physical_Activity_Min_Per_Day      3000 non-null   int64
#  10  Water_Intake_Liters                3000 non-null   float64
#  11  Stress_Level_1to5                  3000 non-null   int64
#  12  Screen_Time_Hours                  3000 non-null   float64
#  13  Smoking_Status                     3000 non-null   object
#  14  Alcohol_Intake_Frequency           2275 non-null   object
#  15  Chronic_Disease_Flag               3000 non-null   int64
#  16  Work_Hours_Per_Day                 3000 non-null   float64
#  17  Step_Count_Per_Day                 3000 non-null   int64
#  18  Fruit_Veg_Servings_Per_Day         3000 non-null   int64
#  19  Coffee_Cups_Per_Day                3000 non-null   int64
#  20  Processed_Food_Frequency_Per_Week  3000 non-null   int64
#  21  Lifestyle_Score                    3000 non-null   float64
# dtypes: float64(9), int64(8), object(5)
# memory usage: 515.8+ KB
# None
#                Age  Sleep_Duration_Hours    Height_cm    Weight_kg  \
# count  3000.000000           3000.000000  3000.000000  3000.000000
# mean     43.563000              6.983633   165.069100    68.006800
# std      14.941791              1.432054     9.973753    11.411006
# min      18.000000              4.000000   145.000000    45.000000
# 25%      31.000000              6.000000   158.000000    60.100000
# 50%      44.000000              7.000000   164.900000    67.900000
# 75%      56.000000              8.000000   172.000000    75.700000
# max      69.000000             10.000000   190.000000   108.500000
#
#                BMI  Dinner_to_Bed_Gap_Hours  Physical_Activity_Min_Per_Day  \
# count  3000.000000              3000.000000                    3000.000000
# mean     25.234333                 2.534500                      60.968000
# std       5.245139                 0.973366                      35.114964
# min      12.500000                 0.500000                       0.000000
# 25%      21.400000                 1.900000                      31.000000
# 50%      24.900000                 2.500000                      61.000000
# 75%      28.600000                 3.200000                      92.000000
# max      45.500000                 5.000000                     120.000000
#
#        Water_Intake_Liters  Stress_Level_1to5  Screen_Time_Hours  \
# count          3000.000000        3000.000000        3000.000000
# mean              2.520367           3.006000           5.015600
# std               0.686770           1.414201           1.962745
# min               0.500000           1.000000           1.000000
# 25%               2.000000           2.000000           3.600000
# 50%               2.500000           3.000000           5.000000
# 75%               3.000000           4.000000           6.400000
# max               4.700000           5.000000          10.000000
#
#        Chronic_Disease_Flag  Work_Hours_Per_Day  Step_Count_Per_Day  \
# count           3000.000000         3000.000000         3000.000000
# mean               0.493667            7.986067         8523.494333
# std                0.500043            1.942329         4361.684276
# min                0.000000            4.000000         1005.000000
# 25%                0.000000            6.600000         4787.750000
# 50%                0.000000            8.000000         8422.500000
# 75%                1.000000            9.300000        12383.250000
# max                1.000000           14.000000        15996.000000
#
#        Fruit_Veg_Servings_Per_Day  Coffee_Cups_Per_Day  \
# count                 3000.000000          3000.000000
# mean                     3.523333             2.963333
# std                      2.283826             1.998663
# min                      0.000000             0.000000
# 25%                      2.000000             1.000000
# 50%                      4.000000             3.000000
# 75%                      5.000000             5.000000
# max                      7.000000             6.000000
#
#        Processed_Food_Frequency_Per_Week  Lifestyle_Score
# count                        3000.000000      3000.000000
# mean                            3.439667        13.704867
# std                             2.265407         6.654727
# min                             0.000000         0.000000
# 25%                             1.000000         9.000000
# 50%                             3.000000        13.800000
# 75%                             5.000000        18.300000
# max                             7.000000        34.500000

# %% [markdown]
# Feature Engineering

# %%
df = df.copy()

# Recompute BMI
df["Height_m"] = df["Height_cm"] / 100.0
df["BMI"] = df["Weight_kg"] / (df["Height_m"] ** 2)

# Binary flags for fuzzy + NN
df["Bilirubin_Flag"] = df["Bilirubin_Issue"].map({"No": 0, "Yes": 1})
df["Gastric_Flag"]   = df["Gastric_Problem"].map({"No": 0, "Yes": 1})

# Meal quality for fuzzy system
meal_quality_map = {
    "Fast Food": 0,
    "Rice-based": 1,
    "Roti-based": 1,
    "Mixed Veg": 2,
    "High Protein": 3
}
df["Meal_Quality"] = df["Meal_Type"].map(meal_quality_map)

# One-hot encode categorical variables for NN
df_nn = pd.get_dummies(
    df,
    columns=["Meal_Type", "Smoking_Status", "Alcohol_Intake_Frequency"],
    drop_first=True
)

feature_cols = [
    "Age",
    "Sleep_Duration_Hours",
    "Dinner_to_Bed_Gap_Hours",
    "Height_cm",
    "Weight_kg",
    "BMI",
    "Physical_Activity_Min_Per_Day",
    "Water_Intake_Liters",
    "Stress_Level_1to5",
    "Screen_Time_Hours",
    "Bilirubin_Flag",
    "Gastric_Flag",
    "Chronic_Disease_Flag",
    "Work_Hours_Per_Day",
    "Step_Count_Per_Day",
    "Fruit_Veg_Servings_Per_Day",
    "Coffee_Cups_Per_Day",
    "Processed_Food_Frequency_Per_Week",
] + [c for c in df_nn.columns if c.startswith("Meal_Type_")
     or c.startswith("Smoking_Status_")
     or c.startswith("Alcohol_Intake_Frequency_")]

X = df_nn[feature_cols].values
print("Input feature matrix shape:", X.shape)
# Out:
# Input feature matrix shape: (3000, 26)

# %% [markdown]
# Fuzzy Variables + Membership Functions

# %%
# Antecedents (inputs) – labels MUST match df column names
age      = ctrl.Antecedent(np.arange(15, 81, 1),  'Age')
sleep    = ctrl.Antecedent(np.arange(4, 11, 0.1), 'Sleep_Duration_Hours')
gap      = ctrl.Antecedent(np.arange(0, 6, 0.1),  'Dinner_to_Bed_Gap_Hours')
bmi      = ctrl.Antecedent(np.arange(15, 41, 0.1),'BMI')
meal_q   = ctrl.Antecedent(np.arange(-0.5, 3.6, 0.1), 'Meal_Quality')
activity = ctrl.Antecedent(np.arange(0, 121, 1), 'Physical_Activity_Min_Per_Day')
water    = ctrl.Antecedent(np.arange(0, 5.5, 0.1),'Water_Intake_Liters')
stress   = ctrl.Antecedent(np.arange(1, 5.1, 0.1),'Stress_Level_1to5')
screen   = ctrl.Antecedent(np.arange(0, 11, 0.1),'Screen_Time_Hours')
bili     = ctrl.Antecedent(np.arange(-0.1, 1.1, 0.1),'Bilirubin_Flag')
gastric  = ctrl.Antecedent(np.arange(-0.1, 1.1, 0.1),'Gastric_Flag')

# Consequent (output) – INTERNAL NAME = 'Lifestyle_Score_Fuzzy'
lifestyle_fuzzy = ctrl.Consequent(np.arange(0, 101, 1), 'Lifestyle_Score_Fuzzy')

# ---- Age ----
age['young']  = fuzz.trapmf(age.universe,  [15, 15, 25, 35])
age['middle'] = fuzz.trimf(age.universe,   [30, 40, 55])
age['old']    = fuzz.trapmf(age.universe,  [50, 60, 80, 80])

# ---- Sleep ----
sleep['poor']      = fuzz.trapmf(sleep.universe, [4, 4, 5, 6])
sleep['normal']    = fuzz.trimf(sleep.universe,  [6, 7.5, 9])
sleep['excellent'] = fuzz.trapmf(sleep.universe, [8, 9, 10, 10])

# ---- Dinner-to-bed gap ----
gap['short'] = fuzz.trapmf(gap.universe, [0, 0, 1, 2])
gap['ok']    = fuzz.trimf(gap.universe,  [2, 3, 4])
gap['long']  = fuzz.trapmf(gap.universe, [4, 4.5, 5, 5])

# ---- BMI ----
bmi['under']  = fuzz.trapmf(bmi.universe, [15, 15, 18, 19])
bmi['normal'] = fuzz.trimf(bmi.universe,  [19, 22, 25])
bmi['over']   = fuzz.trimf(bmi.universe,  [25, 28, 30])
bmi['obese']  = fuzz.trapmf(bmi.universe, [30, 32, 40, 40])

# ---- Meal quality ----
meal_q['poor'] = fuzz.trapmf(meal_q.universe, [-0.5, -0.5, 0, 1])
meal_q['avg']  = fuzz.trimf(meal_q.universe,  [0.8, 1.5, 2.2])
meal_q['good'] = fuzz.trapmf(meal_q.universe, [2, 2.5, 3.5, 3.5])

# ---- Physical activity ----
activity['low']  = fuzz.trapmf(activity.universe, [0, 0, 20, 40])
activity['med']  = fuzz.trimf(activity.universe,  [30, 60, 90])
activity['high'] = fuzz.trapmf(activity.universe, [80, 100, 120, 120])

# ---- Water intake ----
water['low']  = fuzz.trapmf(water.universe, [0, 0, 1.5, 2.0])
water['ok']   = fuzz.trimf(water.universe,  [1.8, 2.5, 3.5])
water['high'] = fuzz.trapmf(water.universe, [3.2, 4.0, 5.5, 5.5])

# ---- Stress ----
stress['low']  = fuzz.trapmf(stress.universe, [1, 1, 1.5, 2.5])
stress['med']  = fuzz.trimf(stress.universe,  [2, 3, 4])
stress['high'] = fuzz.trapmf(stress.universe, [3.5, 4, 5, 5])

# ---- Screen time ----
screen['low']  = fuzz.trapmf(screen.universe, [0, 0, 2, 3])
screen['med']  = fuzz.trimf(screen.universe,  [2.5, 5, 7])
screen['high'] = fuzz.trapmf(screen.universe, [6, 8, 10, 10])

# ---- Bilirubin flag ----
bili['no']  = fuzz.trapmf(bili.universe, [-0.1, -0.1, 0, 0.3])
bili['yes'] = fuzz.trapmf(bili.universe, [0.7, 1, 1.1, 1.1])

# ---- Gastric flag ----
gastric['no']  = fuzz.trapmf(gastric.universe, [-0.1, -0.1, 0, 0.3])
gastric['yes'] = fuzz.trapmf(gastric.universe, [0.7, 1, 1.1, 1.1])

# ---- Output lifestyle fuzzy MFs ----
lifestyle_fuzzy['very_low']  = fuzz.trapmf(lifestyle_fuzzy.universe, [0, 0, 20, 35])
lifestyle_fuzzy['low']       = fuzz.trimf(lifestyle_fuzzy.universe,  [25, 35, 50])
lifestyle_fuzzy['medium']    = fuzz.trimf(lifestyle_fuzzy.universe,  [45, 55, 70])
lifestyle_fuzzy['high']      = fuzz.trimf(lifestyle_fuzzy.universe,  [65, 80, 90])
lifestyle_fuzzy['excellent'] = fuzz.trapmf(lifestyle_fuzzy.universe, [85, 90, 100, 100])

# %% [markdown]
# PRINT ALL FUZZY VARIABLES & THEIR TERMS

# %%
# ---------------------------------------------------------
# PRINT FUZZY VARIABLES & THEIR LINGUISTIC TERMS
# ---------------------------------------------------------

fuzzy_vars = [
    age, sleep, gap, bmi, meal_q, activity,
    water, stress, screen, bili, gastric,
    lifestyle_fuzzy
]

print("\n=========== FUZZY VARIABLES & TERMS ===========\n")

for var in fuzzy_vars:
    print(f"Fuzzy Variable: {var.label}")
    print("Terms:", list(var.terms.keys()))
    print("-" * 50)
# Out:
# =========== FUZZY VARIABLES & TERMS ===========
#
# Fuzzy Variable: Age
# Terms: ['young', 'middle', 'old']
# --------------------------------------------------
# Fuzzy Variable: Sleep_Duration_Hours
# Terms: ['poor', 'normal', 'excellent']
# --------------------------------------------------
# Fuzzy Variable: Dinner_to_Bed_Gap_Hours
# Terms: ['short', 'ok', 'long']
# --------------------------------------------------
# Fuzzy Variable: BMI
# Terms: ['under', 'normal', 'over', 'obese']
# --------------------------------------------------
# Fuzzy Variable: Meal_Quality
# Terms: ['poor', 'avg', 'good']
# --------------------------------------------------
# Fuzzy Variable: Physical_Activity_Min_Per_Day
# Terms: ['low', 'med', 'high']
# --------------------------------------------------
# Fuzzy Variable: Water_Intake_Liters
# Terms: ['low', 'ok', 'high']
# --------------------------------------------------
# Fuzzy Variable: Stress_Level_1to5
# Terms: ['low', 'med', 'high']
# --------------------------------------------------
# Fuzzy Variable: Screen_Time_Hours
# Terms: ['low', 'med', 'high']
# --------------------------------------------------
# Fuzzy Variable: Bilirubin_Flag
# Terms: ['no', 'yes']
# --------------------------------------------------
# Fuzzy Variable: Gastric_Flag
# Terms: ['no', 'yes']
# --------------------------------------------------
# Fuzzy Variable: Lifestyle_Score_Fuzzy
# Terms: ['very_low', 'low', 'medium', 'high', 'excellent']
# --------------------------------------------------

# %% [markdown]
# PRINT MEMBERSHIP FUNCTION NUMERIC RANGES

# %%
# ---------------------------------------------------------
# PRINT FUZZY VARIABLE UNIVERSE RANGES
# ---------------------------------------------------------

print("\n=========== FUZZY VARIABLE RANGES ===========\n")

for var in fuzzy_vars:
    print(f"{var.label} Range: {var.universe.min()}  to  {var.universe.max()}")
# Out:
# =========== FUZZY VARIABLE RANGES ===========
#
# Age Range: 15  to  80
# Sleep_Duration_Hours Range: 4.0  to  10.899999999999975
# Dinner_to_Bed_Gap_Hours Range: 0.0  to  5.9
# BMI Range: 15.0  to  40.899999999999906
# Meal_Quality Range: -0.5  to  3.499999999999999
# Physical_Activity_Min_Per_Day Range: 0  to  120
# Water_Intake_Liters Range: 0.0  to  5.4
# Stress_Level_1to5 Range: 1.0  to  5.0000000000000036
# Screen_Time_Hours Range: 0.0  to  10.9
# Bilirubin_Flag Range: -0.1  to  1.1
# Gastric_Flag Range: -0.1  to  1.1
# Lifestyle_Score_Fuzzy Range: 0  to  100

# %% [markdown]
# View Membership Functions

# %%
# ----------- VISUALIZE ALL MEMBERSHIP FUNCTIONS -----------

# Inputs
age.view(); plt.show()
sleep.view(); plt.show()
gap.view(); plt.show()
bmi.view(); plt.show()
meal_q.view(); plt.show()
activity.view(); plt.show()
water.view(); plt.show()
stress.view(); plt.show()
screen.view(); plt.show()
bili.view(); plt.show()
gastric.view(); plt.show()

# Output
lifestyle_fuzzy.view(); plt.show()

# %% [markdown]
# Fuzzy Rules & Control System

# %%
rule1 = ctrl.Rule(
    sleep['poor'] & stress['high'] & activity['low'],
    lifestyle_fuzzy['very_low']
)

rule2 = ctrl.Rule(
    meal_q['poor'] & gap['short'] & gastric['yes'],
    lifestyle_fuzzy['low']
)

rule3 = ctrl.Rule(
    bmi['normal'] & meal_q['good'] & activity['high'] & sleep['normal'],
    lifestyle_fuzzy['high']
)

rule4 = ctrl.Rule(
    sleep['excellent'] & water['high'] & stress['low'] & screen['low'],
    lifestyle_fuzzy['excellent']
)

rule5 = ctrl.Rule(
    bmi['obese'] & screen['high'] & activity['low'],
    lifestyle_fuzzy['low']
)

rule6 = ctrl.Rule(
    (bili['yes'] | gastric['yes']) & stress['high'],
    lifestyle_fuzzy['very_low']
)

rule7 = ctrl.Rule(
    sleep['normal'] & meal_q['avg'] & activity['med'] & stress['med'],
    lifestyle_fuzzy['medium']
)

rule8 = ctrl.Rule(
    age['old'] & bmi['obese'],
    lifestyle_fuzzy['very_low']
)

lifestyle_ctrl = ctrl.ControlSystem([
    rule1, rule2, rule3, rule4,
    rule5, rule6, rule7, rule8
])

# %% [markdown]
# PRINT ALL FUZZY RULES IN SIMPLE TEXT FORM

# %%
# ---------------------------------------------------------
# PRINT ALL FUZZY RULES
# ---------------------------------------------------------

print("\n=========== FUZZY RULE BASE ===========\n")

for i, rule in enumerate(lifestyle_ctrl.rules, start=1):
    print(f"Rule {i}:")
    print(rule)
    print("-" * 60)
# Out:
# =========== FUZZY RULE BASE ===========
#
# Rule 1:
# IF (Sleep_Duration_Hours[poor] AND Stress_Level_1to5[high]) AND Physical_Activity_Min_Per_Day[low] THEN Lifestyle_Score_Fuzzy[very_low]
# 	AND aggregation function : fmin
# 	OR aggregation function  : fmax
# ------------------------------------------------------------
# Rule 2:
# IF (Meal_Quality[poor] AND Dinner_to_Bed_Gap_Hours[short]) AND Gastric_Flag[yes] THEN Lifestyle_Score_Fuzzy[low]
# 	AND aggregation function : fmin
# 	OR aggregation function  : fmax
# ------------------------------------------------------------
# Rule 3:
# IF ((BMI[normal] AND Meal_Quality[good]) AND Physical_Activity_Min_Per_Day[high]) AND Sleep_Duration_Hours[normal] THEN Lifestyle_Score_Fuzzy[high]
# 	AND aggregation function : fmin
# 	OR aggregation function  : fmax
# ------------------------------------------------------------
# Rule 4:
# IF ((Sleep_Duration_Hours[excellent] AND Water_Intake_Liters[high]) AND Stress_Level_1to5[low]) AND Screen_Time_Hours[low] THEN Lifestyle_Score_Fuzzy[excellent]
# 	AND aggregation function : fmin
# 	OR aggregation function  : fmax
# ------------------------------------------------------------
# Rule 5:
# IF (BMI[obese] AND Screen_Time_Hours[high]) AND Physical_Activity_Min_Per_Day[low] THEN Lifestyle_Score_Fuzzy[low]
# 	AND aggregation function : fmin
# 	OR aggregation function  : fmax
# ------------------------------------------------------------
# Rule 6:
# IF (Bilirubin_Flag[yes] OR Gastric_Flag[yes]) AND Stress_Level_1to5[high] THEN Lifestyle_Score_Fuzzy[very_low]
# 	AND aggregation function : fmin
# 	OR aggregation function  : fmax
# ------------------------------------------------------------
# Rule 7:
# IF ((Sleep_Duration_Hours[normal] AND Meal_Quality[avg]) AND Physical_Activity_Min_Per_Day[med]) AND Stress_Level_1to5[med] THEN Lifestyle_Score_Fuzzy[medium]
# 	AND aggregation function : fmin
# 	OR aggregation function  : fmax
# ------------------------------------------------------------
# Rule 8:
# IF Age[old] AND BMI[obese] THEN Lifestyle_Score_Fuzzy[very_low]
# 	AND aggregation function : fmin
# 	OR aggregation function  : fmax
# ------------------------------------------------------------

# %% [markdown]
# PRINT FUZZIFICATION VALUES FOR ONE SAMPLE

# %%
# ---------------------------------------------------------
# PRINT FUZZIFICATION VALUES FOR ONE SAMPLE
# ---------------------------------------------------------

sample_index = 0
row = df.iloc[sample_index]

sim = ctrl.ControlSystemSimulation(lifestyle_ctrl)

sim.input['Age']                           = row['Age']
sim.input['Sleep_Duration_Hours']          = row['Sleep_Duration_Hours']
sim.input['Dinner_to_Bed_Gap_Hours']       = row['Dinner_to_Bed_Gap_Hours']
sim.input['BMI']                           = row['BMI']
sim.input['Meal_Quality']                  = row['Meal_Quality']
sim.input['Physical_Activity_Min_Per_Day'] = row['Physical_Activity_Min_Per_Day']
sim.input['Water_Intake_Liters']           = row['Water_Intake_Liters']
sim.input['Stress_Level_1to5']             = row['Stress_Level_1to5']
sim.input['Screen_Time_Hours']             = row['Screen_Time_Hours']
sim.input['Bilirubin_Flag']                = row['Bilirubin_Flag']
sim.input['Gastric_Flag']                  = row['Gastric_Flag']

print("\n=========== FUZZIFICATION VALUES (Membership Degrees) ===========\n")

for var in [age, sleep, gap, bmi, meal_q, activity, water, stress, screen, bili, gastric]:
    print(f"\n{var.label}:")
    for term in var.terms:
        membership = fuzz.interp_membership(
            var.universe, var[term].mf, row[var.label]
        )
        print(f"  {term} → {membership:.3f}")
# Out:
# =========== FUZZIFICATION VALUES (Membership Degrees) ===========
#
#
# Age:
#   young → 0.000
#   middle → 0.000
#   old → 0.600
#
# Sleep_Duration_Hours:
#   poor → 0.000
#   normal → 0.467
#   excellent → 0.300
#
# Dinner_to_Bed_Gap_Hours:
#   short → 0.000
#   ok → 0.600
#   long → 0.000
#
# BMI:
#   under → 0.000
#   normal → 0.000
#   over → 0.384
#   obese → 0.000
#
# Meal_Quality:
#   poor → 0.000
#   avg → 0.000
#   good → 1.000
#
# Physical_Activity_Min_Per_Day:
#   low → 0.000
#   med → 0.000
#   high → 1.000
#
# Water_Intake_Liters:
#   low → 0.200
#   ok → 0.143
#   high → 0.000
#
# Stress_Level_1to5:
#   low → 0.000
#   med → 0.000
#   high → 0.000
#
# Screen_Time_Hours:
#   low → 0.000
#   med → 0.800
#   high → 0.000
#
# Bilirubin_Flag:
#   no → 1.000
#   yes → 0.000
#
# Gastric_Flag:
#   no → 0.000
#   yes → 1.000

# %% [markdown]
# PRINT RULE FIRING STRENGTHS

# %%
# ---------------------------------------------------------
# PRINT RULE FIRING STRENGTHS
# ---------------------------------------------------------

sim.compute()

print("\n=========== RULE FIRING STRENGTHS ===========\n")

for i, rule in enumerate(lifestyle_ctrl.rules, start=1):
    print(f"Rule {i} firing strength: {rule.aggregate_firing[sim]:.4f}")
# Out:
# =========== RULE FIRING STRENGTHS ===========
#
# Rule 1 firing strength: 0.0000
# Rule 2 firing strength: 0.0000
# Rule 3 firing strength: 0.0000
# Rule 4 firing strength: 0.0000
# Rule 5 firing strength: 0.0000
# Rule 6 firing strength: 0.0000
# Rule 7 firing strength: 0.0000
# Rule 8 firing strength: 0.0000

# %% [markdown]
# Fuzzy Score + Explanation Function

# %%
def compute_fuzzy_score_and_explanation(row):
    sim = ctrl.ControlSystemSimulation(lifestyle_ctrl)

    # Inputs
    sim.input['Age']                           = row['Age']
    sim.input['Sleep_Duration_Hours']          = row['Sleep_Duration_Hours']
    sim.input['Dinner_to_Bed_Gap_Hours']       = row['Dinner_to_Bed_Gap_Hours']
    sim.input['BMI']                           = row['BMI']
    sim.input['Meal_Quality']                  = row['Meal_Quality']
    sim.input['Physical_Activity_Min_Per_Day'] = row['Physical_Activity_Min_Per_Day']
    sim.input['Water_Intake_Liters']           = row['Water_Intake_Liters']
    sim.input['Stress_Level_1to5']             = row['Stress_Level_1to5']
    sim.input['Screen_Time_Hours']             = row['Screen_Time_Hours']
    sim.input['Bilirubin_Flag']                = row['Bilirubin_Flag']
    sim.input['Gastric_Flag']                  = row['Gastric_Flag']

    # Run fuzzy inference
    sim.compute()

    out_keys = list(sim.output.keys())
    if len(out_keys) == 0:
        score = np.nan
    else:
        score = sim.output[out_keys[0]]

    # Build explanation based on crisp input values
    reasons = []
    if row['Sleep_Duration_Hours'] < 6:
        reasons.append("short sleep")
    if row['Dinner_to_Bed_Gap_Hours'] < 2:
        reasons.append("short dinner–sleep gap")
    if row['BMI'] >= 30:
        reasons.append("high BMI (obesity)")
    if row['Meal_Quality'] <= 0.5:
        reasons.append("unhealthy / fast food pattern")
    if row['Physical_Activity_Min_Per_Day'] < 30:
        reasons.append("low physical activity")
    if row['Water_Intake_Liters'] < 2:
        reasons.append("low water intake")
    if row['Stress_Level_1to5'] >= 4:
        reasons.append("high stress")
    if row['Screen_Time_Hours'] >= 7:
        reasons.append("high screen time")
    if row['Bilirubin_Flag'] == 1:
        reasons.append("bilirubin issue")
    if row['Gastric_Flag'] == 1:
        reasons.append("gastric problem")

    explanation = (
        "Low score factors: " + ", ".join(reasons)
        if reasons else
        "Healthy lifestyle pattern."
    )

    return score, explanation


# ---- Apply to whole dataset ----
fuzzy_scores = []
explanations = []

for _, r in df.iterrows():
    s, e = compute_fuzzy_score_and_explanation(r)
    fuzzy_scores.append(s)
    explanations.append(e)

df["Fuzzy_Lifestyle_Score"] = fuzzy_scores
df["Fuzzy_Explanation"] = explanations

df[["Lifestyle_Score", "Fuzzy_Lifestyle_Score", "Fuzzy_Explanation"]].head()
# Out:
#    Lifestyle_Score  Fuzzy_Lifestyle_Score  \
# 0             18.2              17.500000
# 1              4.9              14.090909
# 2              0.5              17.500000
# 3             18.9              14.090909
# 4              0.0              19.015601
#
#                                    Fuzzy_Explanation
# 0  Low score factors: low water intake, high stre...
# 1  Low score factors: short sleep, low physical a...
# 2  Low score factors: short dinner–sleep gap, hig...
# 3  Low score factors: high stress, bilirubin issu...
# 4  Low score factors: high BMI (obesity), unhealt...

# %% [markdown]
# Correlation of key features with Lifestyle_Score

# %%
corr_cols = [
    "Lifestyle_Score",
    "Fuzzy_Lifestyle_Score",
    "Sleep_Duration_Hours",
    "BMI",
    "Physical_Activity_Min_Per_Day",
    "Water_Intake_Liters",
    "Stress_Level_1to5",
    "Screen_Time_Hours",
    "Fruit_Veg_Servings_Per_Day",
]

corr_table = df[corr_cols].corr().round(2)
corr_table
# Out:
#                                Lifestyle_Score  Fuzzy_Lifestyle_Score  \
# Lifestyle_Score                           1.00                   0.38
# Fuzzy_Lifestyle_Score                     0.38                   1.00
# Sleep_Duration_Hours                      0.29                   0.11
# BMI                                      -0.26                  -0.19
# Physical_Activity_Min_Per_Day             0.71                   0.11
# Water_Intake_Liters                       0.15                   0.09
# Stress_Level_1to5                        -0.43                  -0.56
# Screen_Time_Hours                        -0.17                  -0.03
# Fruit_Veg_Servings_Per_Day                0.27                   0.03
#
#                                Sleep_Duration_Hours   BMI  \
# Lifestyle_Score                                0.29 -0.26
# Fuzzy_Lifestyle_Score                          0.11 -0.19
# Sleep_Duration_Hours                           1.00  0.02
# BMI                                            0.02  1.00
# Physical_Activity_Min_Per_Day                  0.02 -0.01
# Water_Intake_Liters                            0.02 -0.03
# Stress_Level_1to5                              0.01  0.01
# Screen_Time_Hours                             -0.02 -0.02
# Fruit_Veg_Servings_Per_Day                    -0.00  0.01
#
#                                Physical_Activity_Min_Per_Day  \
# Lifestyle_Score                                         0.71
# Fuzzy_Lifestyle_Score                                   0.11
# Sleep_Duration_Hours                                    0.02
# BMI                                                    -0.01
# Physical_Activity_Min_Per_Day                           1.00
# Water_Intake_Liters                                     0.01
# Stress_Level_1to5                                      -0.03
# Screen_Time_Hours                                      -0.02
# Fruit_Veg_Servings_Per_Day                             -0.02
#
#                                Water_Intake_Liters  Stress_Level_1to5  \
# Lifestyle_Score                               0.15              -0.43
# Fuzzy_Lifestyle_Score                         0.09              -0.56
# Sleep_Duration_Hours                          0.02               0.01
# BMI                                          -0.03               0.01
# Physical_Activity_Min_Per_Day                 0.01              -0.03
# Water_Intake_Liters                           1.00              -0.00
# Stress_Level_1to5                            -0.00               1.00
# Screen_Time_Hours                            -0.02              -0.01
# Fruit_Veg_Servings_Per_Day                   -0.03              -0.01
#
#                                Screen_Time_Hours  Fruit_Veg_Servings_Per_Day
# Lifestyle_Score                            -0.17                        0.27
# Fuzzy_Lifestyle_Score                      -0.03                        0.03
# Sleep_Duration_Hours                       -0.02                       -0.00
# BMI                                        -0.02                        0.01
# Physical_Activity_Min_Per_Day              -0.02                       -0.02
# Water_Intake_Liters                        -0.02                       -0.03
# Stress_Level_1to5                          -0.01                       -0.01
# Screen_Time_Hours                           1.00                       -0.01
# Fruit_Veg_Servings_Per_Day                 -0.01                        1.00

# %% [markdown]
# Dataset Score vs Fuzzy Score

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(x=df["Lifestyle_Score"], y=df["Fuzzy_Lifestyle_Score"], alpha=0.4)
plt.xlabel("Original Lifestyle_Score (Dataset)")
plt.ylabel("Fuzzy_Lifestyle_Score")
plt.title("Dataset vs Fuzzy Lifestyle Score")
plt.grid(True)
plt.show()

# %% [markdown]
# Fuzzy + ANN

# %%
# =========================================================
# BLOCK A: Fuzzy + ANN (Fuzzy_Lifestyle_Score as input)
# =========================================================

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.callbacks import EarlyStopping

# 1) Attach fuzzy score to NN dataframe
assert "Fuzzy_Lifestyle_Score" in df.columns, "Run fuzzy block first."
df_nn["Fuzzy_Lifestyle_Score"] = df["Fuzzy_Lifestyle_Score"]

# 2) Feature list including fuzzy score
feature_cols_with_fuzzy = feature_cols + ["Fuzzy_Lifestyle_Score"]

# 3) Remove any rows with NaN in features or target (very important to avoid NaN loss)
valid_mask_fuzzy = (
    df_nn[feature_cols_with_fuzzy].notna().all(axis=1)
    & df["Lifestyle_Score"].notna()
)

df_fuzzy = df[valid_mask_fuzzy].copy()
df_nn_fuzzy = df_nn[valid_mask_fuzzy].copy()

# 4) Build X and y
X_fuzzy = df_nn_fuzzy[feature_cols_with_fuzzy].values
y_fuzzy = df_fuzzy["Lifestyle_Score"].values / 100.0  # scale 0–1

print("Fuzzy+ANN: X shape =", X_fuzzy.shape, " y shape =", y_fuzzy.shape)

# 5) Train–test split
Xf_train, Xf_test, yf_train, yf_test = train_test_split(
    X_fuzzy, y_fuzzy, test_size=0.2, random_state=42
)

# 6) Scaling
scaler_fuzzy = StandardScaler()
Xf_train_scaled = scaler_fuzzy.fit_transform(Xf_train)
Xf_test_scaled  = scaler_fuzzy.transform(Xf_test)

print("Any NaN in Xf_train_scaled?", np.isnan(Xf_train_scaled).any())
print("Any NaN in yf_train?", np.isnan(yf_train).any())

# 7) Build and train model
model_fuzzy = keras.Sequential([
    layers.Input(shape=(Xf_train_scaled.shape[1],)),
    layers.Dense(64, activation="relu"),
    layers.Dense(32, activation="relu"),
    layers.Dense(1, activation="linear")
])

model_fuzzy.compile(optimizer="adam", loss="mse", metrics=["mae"])

early_stop_fuzzy = EarlyStopping(
    monitor="val_loss",
    patience=10,
    restore_best_weights=True
)

history_fuzzy = model_fuzzy.fit(
    Xf_train_scaled, yf_train,
    validation_split=0.2,
    epochs=100,
    batch_size=32,
    callbacks=[early_stop_fuzzy],
    verbose=1
)

# 8) Evaluation
test_loss_fuzzy, test_mae_fuzzy = model_fuzzy.evaluate(Xf_test_scaled, yf_test, verbose=0)
print("Fuzzy+ANN Test MSE:", test_loss_fuzzy)
print("Fuzzy+ANN Test MAE (0–1):", test_mae_fuzzy)
print("Fuzzy+ANN Test MAE in score points:", test_mae_fuzzy * 100)
print("Fuzzy+ANN Epochs actually run:", len(history_fuzzy.history["loss"]))
# Out:
# Fuzzy+ANN: X shape = (1543, 27)  y shape = (1543,)
# Any NaN in Xf_train_scaled? False
# Any NaN in yf_train? False
# Epoch 1/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 6s 47ms/step - loss: 0.1218 - mae: 0.2662 - val_loss: 0.0432 - val_mae: 0.1591
# Epoch 2/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 0.0283 - mae: 0.1344 - val_loss: 0.0274 - val_mae: 0.1312
# Epoch 3/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0166 - mae: 0.1031 - val_loss: 0.0221 - val_mae: 0.1167
# Epoch 4/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0110 - mae: 0.0846 - val_loss: 0.0189 - val_mae: 0.1087
# Epoch 5/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0081 - mae: 0.0726 - val_loss: 0.0164 - val_mae: 0.1005
# Epoch 6/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0066 - mae: 0.0653 - val_loss: 0.0146 - val_mae: 0.0945
# Epoch 7/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0051 - mae: 0.0569 - val_loss: 0.0133 - val_mae: 0.0912
# Epoch 8/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0049 - mae: 0.0563 - val_loss: 0.0125 - val_mae: 0.0875
# Epoch 9/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0038 - mae: 0.0483 - val_loss: 0.0118 - val_mae: 0.0849
# Epoch 10/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0032 - mae: 0.0450 - val_loss: 0.0110 - val_mae: 0.0819
# Epoch 11/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0026 - mae: 0.0407 - val_loss: 0.0105 - val_mae: 0.0805
# Epoch 12/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0024 - mae: 0.0374 - val_loss: 0.0102 - val_mae: 0.0788
# Epoch 13/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0021 - mae: 0.0358 - val_loss: 0.0099 - val_mae: 0.0780
# Epoch 14/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0018 - mae: 0.0341 - val_loss: 0.0095 - val_mae: 0.0770
# Epoch 15/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0017 - mae: 0.0322 - val_loss: 0.0093 - val_mae: 0.0759
# Epoch 16/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0014 - mae: 0.0293 - val_loss: 0.0089 - val_mae: 0.0742
# Epoch 17/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0013 - mae: 0.0282 - val_loss: 0.0088 - val_mae: 0.0742
# Epoch 18/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0011 - mae: 0.0264 - val_loss: 0.0084 - val_mae: 0.0727
# Epoch 19/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0011 - mae: 0.0258 - val_loss: 0.0085 - val_mae: 0.0733
# Epoch 20/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.0157e-04 - mae: 0.0235 - val_loss: 0.0082 - val_mae: 0.0717
# Epoch 21/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.2538e-04 - mae: 0.0221 - val_loss: 0.0080 - val_mae: 0.0715
# Epoch 22/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.6494e-04 - mae: 0.0222 - val_loss: 0.0078 - val_mae: 0.0705
# Epoch 23/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.2027e-04 - mae: 0.0213 - val_loss: 0.0077 - val_mae: 0.0700
# Epoch 24/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.6276e-04 - mae: 0.0199 - val_loss: 0.0076 - val_mae: 0.0699
# Epoch 25/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.6131e-04 - mae: 0.0187 - val_loss: 0.0074 - val_mae: 0.0687
# Epoch 26/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.3048e-04 - mae: 0.0181 - val_loss: 0.0074 - val_mae: 0.0691
# Epoch 27/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.8292e-04 - mae: 0.0173 - val_loss: 0.0073 - val_mae: 0.0682
# Epoch 28/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.3871e-04 - mae: 0.0162 - val_loss: 0.0073 - val_mae: 0.0683
# Epoch 29/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.5021e-04 - mae: 0.0168 - val_loss: 0.0071 - val_mae: 0.0674
# Epoch 30/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.1323e-04 - mae: 0.0158 - val_loss: 0.0071 - val_mae: 0.0676
# Epoch 31/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.3304e-04 - mae: 0.0146 - val_loss: 0.0070 - val_mae: 0.0670
# Epoch 32/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.4531e-04 - mae: 0.0142 - val_loss: 0.0069 - val_mae: 0.0668
# Epoch 33/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0113e-04 - mae: 0.0138 - val_loss: 0.0069 - val_mae: 0.0668
# Epoch 34/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.6734e-04 - mae: 0.0128 - val_loss: 0.0068 - val_mae: 0.0661
# Epoch 35/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5834e-04 - mae: 0.0129 - val_loss: 0.0068 - val_mae: 0.0663
# Epoch 36/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5671e-04 - mae: 0.0126 - val_loss: 0.0068 - val_mae: 0.0662
# Epoch 37/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3575e-04 - mae: 0.0122 - val_loss: 0.0066 - val_mae: 0.0657
# Epoch 38/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1490e-04 - mae: 0.0114 - val_loss: 0.0067 - val_mae: 0.0659
# Epoch 39/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1863e-04 - mae: 0.0117 - val_loss: 0.0066 - val_mae: 0.0654
# Epoch 40/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9237e-04 - mae: 0.0107 - val_loss: 0.0066 - val_mae: 0.0653
# Epoch 41/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6139e-04 - mae: 0.0099 - val_loss: 0.0065 - val_mae: 0.0651
# Epoch 42/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4726e-04 - mae: 0.0096 - val_loss: 0.0065 - val_mae: 0.0652
# Epoch 43/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4447e-04 - mae: 0.0093 - val_loss: 0.0065 - val_mae: 0.0649
# Epoch 44/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2771e-04 - mae: 0.0090 - val_loss: 0.0063 - val_mae: 0.0643
# Epoch 45/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3003e-04 - mae: 0.0090 - val_loss: 0.0064 - val_mae: 0.0646
# Epoch 46/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1521e-04 - mae: 0.0083 - val_loss: 0.0064 - val_mae: 0.0646
# Epoch 47/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2439e-04 - mae: 0.0087 - val_loss: 0.0063 - val_mae: 0.0640
# Epoch 48/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1201e-04 - mae: 0.0083 - val_loss: 0.0063 - val_mae: 0.0639
# Epoch 49/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.6384e-05 - mae: 0.0077 - val_loss: 0.0063 - val_mae: 0.0638
# Epoch 50/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.0747e-05 - mae: 0.0072 - val_loss: 0.0063 - val_mae: 0.0637
# Epoch 51/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.9505e-05 - mae: 0.0070 - val_loss: 0.0063 - val_mae: 0.0641
# Epoch 52/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.5960e-05 - mae: 0.0063 - val_loss: 0.0062 - val_mae: 0.0634
# Epoch 53/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.6541e-05 - mae: 0.0063 - val_loss: 0.0062 - val_mae: 0.0635
# Epoch 54/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.2451e-05 - mae: 0.0062 - val_loss: 0.0062 - val_mae: 0.0635
# Epoch 55/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.7971e-05 - mae: 0.0060 - val_loss: 0.0062 - val_mae: 0.0634
# Epoch 56/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.5764e-05 - mae: 0.0059 - val_loss: 0.0061 - val_mae: 0.0631
# Epoch 57/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.8766e-05 - mae: 0.0054 - val_loss: 0.0062 - val_mae: 0.0633
# Epoch 58/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.2818e-05 - mae: 0.0056 - val_loss: 0.0062 - val_mae: 0.0634
# Epoch 59/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.1290e-05 - mae: 0.0050 - val_loss: 0.0061 - val_mae: 0.0632
# Epoch 60/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.9905e-05 - mae: 0.0049 - val_loss: 0.0061 - val_mae: 0.0631
# Epoch 61/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.8592e-05 - mae: 0.0048 - val_loss: 0.0061 - val_mae: 0.0630
# Epoch 62/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.9509e-05 - mae: 0.0048 - val_loss: 0.0061 - val_mae: 0.0629
# Epoch 63/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.1964e-05 - mae: 0.0044 - val_loss: 0.0061 - val_mae: 0.0631
# Epoch 64/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9926e-05 - mae: 0.0041 - val_loss: 0.0061 - val_mae: 0.0630
# Epoch 65/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.7709e-05 - mae: 0.0041 - val_loss: 0.0061 - val_mae: 0.0629
# Epoch 66/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8589e-05 - mae: 0.0042 - val_loss: 0.0061 - val_mae: 0.0628
# Epoch 67/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.4306e-05 - mae: 0.0038 - val_loss: 0.0060 - val_mae: 0.0626
# Epoch 68/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9260e-05 - mae: 0.0033 - val_loss: 0.0061 - val_mae: 0.0628
# Epoch 69/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0524e-05 - mae: 0.0035 - val_loss: 0.0061 - val_mae: 0.0630
# Epoch 70/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8635e-05 - mae: 0.0033 - val_loss: 0.0060 - val_mae: 0.0624
# Epoch 71/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9830e-05 - mae: 0.0035 - val_loss: 0.0060 - val_mae: 0.0623
# Epoch 72/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7016e-05 - mae: 0.0032 - val_loss: 0.0060 - val_mae: 0.0626
# Epoch 73/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5117e-05 - mae: 0.0030 - val_loss: 0.0060 - val_mae: 0.0626
# Epoch 74/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6196e-05 - mae: 0.0031 - val_loss: 0.0060 - val_mae: 0.0624
# Epoch 75/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4673e-05 - mae: 0.0029 - val_loss: 0.0060 - val_mae: 0.0625
# Epoch 76/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2123e-05 - mae: 0.0026 - val_loss: 0.0060 - val_mae: 0.0625
# Epoch 77/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1825e-05 - mae: 0.0026 - val_loss: 0.0060 - val_mae: 0.0624
# Epoch 78/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0449e-05 - mae: 0.0025 - val_loss: 0.0060 - val_mae: 0.0625
# Epoch 79/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.4747e-06 - mae: 0.0024 - val_loss: 0.0060 - val_mae: 0.0625
# Epoch 80/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.7651e-06 - mae: 0.0023 - val_loss: 0.0060 - val_mae: 0.0625
# Epoch 81/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.7828e-06 - mae: 0.0021 - val_loss: 0.0060 - val_mae: 0.0624
# Epoch 82/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.6612e-06 - mae: 0.0021 - val_loss: 0.0060 - val_mae: 0.0623
# Epoch 83/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.9712e-06 - mae: 0.0021 - val_loss: 0.0060 - val_mae: 0.0623
# Epoch 84/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.5416e-06 - mae: 0.0018 - val_loss: 0.0059 - val_mae: 0.0623
# Epoch 85/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.1127e-06 - mae: 0.0017 - val_loss: 0.0059 - val_mae: 0.0623
# Epoch 86/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.7711e-06 - mae: 0.0017 - val_loss: 0.0060 - val_mae: 0.0623
# Epoch 87/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.3093e-06 - mae: 0.0016 - val_loss: 0.0059 - val_mae: 0.0624
# Epoch 88/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.4842e-06 - mae: 0.0016 - val_loss: 0.0059 - val_mae: 0.0623
# Epoch 89/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.9737e-06 - mae: 0.0015 - val_loss: 0.0059 - val_mae: 0.0622
# Epoch 90/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.3125e-06 - mae: 0.0014 - val_loss: 0.0059 - val_mae: 0.0621
# Epoch 91/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.4803e-06 - mae: 0.0014 - val_loss: 0.0059 - val_mae: 0.0623
# Epoch 92/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9621e-06 - mae: 0.0013 - val_loss: 0.0059 - val_mae: 0.0621
# Epoch 93/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.4892e-06 - mae: 0.0015 - val_loss: 0.0059 - val_mae: 0.0622
# Epoch 94/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9627e-06 - mae: 0.0013 - val_loss: 0.0059 - val_mae: 0.0622
# Epoch 95/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7773e-06 - mae: 0.0013 - val_loss: 0.0059 - val_mae: 0.0622
# Epoch 96/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3118e-06 - mae: 0.0012 - val_loss: 0.0059 - val_mae: 0.0622
# Epoch 97/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7423e-06 - mae: 0.0013 - val_loss: 0.0059 - val_mae: 0.0621
# Epoch 98/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.6058e-06 - mae: 0.0012 - val_loss: 0.0059 - val_mae: 0.0623
# Epoch 99/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2220e-06 - mae: 0.0011 - val_loss: 0.0059 - val_mae: 0.0620
# Epoch 100/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.4305e-06 - mae: 0.0012 - val_loss: 0.0059 - val_mae: 0.0623
# Fuzzy+ANN Test MSE: 0.005439969711005688
# Fuzzy+ANN Test MAE (0–1): 0.05779051408171654
# Fuzzy+ANN Test MAE in score points: 5.779051408171654
# Fuzzy+ANN Epochs actually run: 100

# %% [markdown]
# Direct ANN (no fuzzy score)

# %%
# =========================================================
# BLOCK B: Direct ANN on Original Features (no fuzzy score)
# =========================================================

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.callbacks import EarlyStopping

# 1) Clean rows for direct ANN (only original feature_cols)
valid_mask_direct = (
    df_nn[feature_cols].notna().all(axis=1)
    & df["Lifestyle_Score"].notna()
)

df_direct = df[valid_mask_direct].copy()
df_nn_direct = df_nn[valid_mask_direct].copy()

# 2) Build X and y (without fuzzy feature)
X_direct = df_nn_direct[feature_cols].values
y_direct = df_direct["Lifestyle_Score"].values / 100.0

print("Direct ANN: X shape =", X_direct.shape, " y shape =", y_direct.shape)

# 3) Train–test split
Xd_train, Xd_test, yd_train, yd_test = train_test_split(
    X_direct, y_direct, test_size=0.2, random_state=42
)

# 4) Scaling
scaler_direct = StandardScaler()
Xd_train_scaled = scaler_direct.fit_transform(Xd_train)
Xd_test_scaled  = scaler_direct.transform(Xd_test)

print("Any NaN in Xd_train_scaled?", np.isnan(Xd_train_scaled).any())
print("Any NaN in yd_train?", np.isnan(yd_train).any())

# 5) Build and train model
model_direct = keras.Sequential([
    layers.Input(shape=(Xd_train_scaled.shape[1],)),
    layers.Dense(64, activation="relu"),
    layers.Dense(32, activation="relu"),
    layers.Dense(1, activation="linear")
])

model_direct.compile(optimizer="adam", loss="mse", metrics=["mae"])

early_stop_direct = EarlyStopping(
    monitor="val_loss",
    patience=10,
    restore_best_weights=True
)

history_direct = model_direct.fit(
    Xd_train_scaled, yd_train,
    validation_split=0.2,
    epochs=100,
    batch_size=32,
    callbacks=[early_stop_direct],
    verbose=1
)

# 6) Evaluation
test_loss_direct, test_mae_direct = model_direct.evaluate(Xd_test_scaled, yd_test, verbose=0)
print("Direct ANN Test MSE:", test_loss_direct)
print("Direct ANN Test MAE (0–1):", test_mae_direct)
print("Direct ANN Test MAE in score points:", test_mae_direct * 100)
print("Direct ANN Epochs actually run:", len(history_direct.history["loss"]))
# Out:
# Direct ANN: X shape = (3000, 26)  y shape = (3000,)
# Any NaN in Xd_train_scaled? False
# Any NaN in yd_train? False
# Epoch 1/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.3171 - mae: 0.4294 - val_loss: 0.0514 - val_mae: 0.1795
# Epoch 2/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0388 - mae: 0.1570 - val_loss: 0.0321 - val_mae: 0.1422
# Epoch 3/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0247 - mae: 0.1250 - val_loss: 0.0234 - val_mae: 0.1203
# Epoch 4/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0157 - mae: 0.0986 - val_loss: 0.0186 - val_mae: 0.1065
# Epoch 5/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0114 - mae: 0.0843 - val_loss: 0.0152 - val_mae: 0.0973
# Epoch 6/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0086 - mae: 0.0729 - val_loss: 0.0129 - val_mae: 0.0892
# Epoch 7/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0073 - mae: 0.0678 - val_loss: 0.0114 - val_mae: 0.0842
# Epoch 8/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0059 - mae: 0.0609 - val_loss: 0.0103 - val_mae: 0.0807
# Epoch 9/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0050 - mae: 0.0561 - val_loss: 0.0093 - val_mae: 0.0767
# Epoch 10/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0043 - mae: 0.0520 - val_loss: 0.0085 - val_mae: 0.0735
# Epoch 11/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0038 - mae: 0.0481 - val_loss: 0.0080 - val_mae: 0.0711
# Epoch 12/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0032 - mae: 0.0448 - val_loss: 0.0074 - val_mae: 0.0688
# Epoch 13/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0030 - mae: 0.0425 - val_loss: 0.0073 - val_mae: 0.0678
# Epoch 14/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0026 - mae: 0.0404 - val_loss: 0.0067 - val_mae: 0.0652
# Epoch 15/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0024 - mae: 0.0388 - val_loss: 0.0063 - val_mae: 0.0631
# Epoch 16/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0023 - mae: 0.0375 - val_loss: 0.0060 - val_mae: 0.0619
# Epoch 17/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0020 - mae: 0.0354 - val_loss: 0.0057 - val_mae: 0.0601
# Epoch 18/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0019 - mae: 0.0340 - val_loss: 0.0055 - val_mae: 0.0593
# Epoch 19/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0016 - mae: 0.0314 - val_loss: 0.0053 - val_mae: 0.0580
# Epoch 20/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015 - mae: 0.0307 - val_loss: 0.0052 - val_mae: 0.0576
# Epoch 21/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0015 - mae: 0.0303 - val_loss: 0.0049 - val_mae: 0.0558
# Epoch 22/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0014 - mae: 0.0300 - val_loss: 0.0048 - val_mae: 0.0552
# Epoch 23/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0013 - mae: 0.0281 - val_loss: 0.0046 - val_mae: 0.0536
# Epoch 24/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0012 - mae: 0.0272 - val_loss: 0.0044 - val_mae: 0.0527
# Epoch 25/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - mae: 0.0260 - val_loss: 0.0043 - val_mae: 0.0520
# Epoch 26/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.8183e-04 - mae: 0.0245 - val_loss: 0.0041 - val_mae: 0.0511
# Epoch 27/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.9358e-04 - mae: 0.0236 - val_loss: 0.0041 - val_mae: 0.0508
# Epoch 28/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.4504e-04 - mae: 0.0230 - val_loss: 0.0040 - val_mae: 0.0496
# Epoch 29/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.0296e-04 - mae: 0.0220 - val_loss: 0.0038 - val_mae: 0.0488
# Epoch 30/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.5446e-04 - mae: 0.0218 - val_loss: 0.0037 - val_mae: 0.0480
# Epoch 31/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.3423e-04 - mae: 0.0215 - val_loss: 0.0036 - val_mae: 0.0473
# Epoch 32/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.1446e-04 - mae: 0.0212 - val_loss: 0.0036 - val_mae: 0.0470
# Epoch 33/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.2613e-04 - mae: 0.0198 - val_loss: 0.0035 - val_mae: 0.0463
# Epoch 34/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.2103e-04 - mae: 0.0200 - val_loss: 0.0034 - val_mae: 0.0460
# Epoch 35/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.8014e-04 - mae: 0.0190 - val_loss: 0.0034 - val_mae: 0.0456
# Epoch 36/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2950e-04 - mae: 0.0181 - val_loss: 0.0033 - val_mae: 0.0449
# Epoch 37/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.3959e-04 - mae: 0.0183 - val_loss: 0.0032 - val_mae: 0.0445
# Epoch 38/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9193e-04 - mae: 0.0176 - val_loss: 0.0032 - val_mae: 0.0446
# Epoch 39/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6018e-04 - mae: 0.0171 - val_loss: 0.0031 - val_mae: 0.0439
# Epoch 40/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5003e-04 - mae: 0.0170 - val_loss: 0.0030 - val_mae: 0.0431
# Epoch 41/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3322e-04 - mae: 0.0165 - val_loss: 0.0030 - val_mae: 0.0433
# Epoch 42/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1248e-04 - mae: 0.0159 - val_loss: 0.0029 - val_mae: 0.0424
# Epoch 43/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5664e-04 - mae: 0.0150 - val_loss: 0.0029 - val_mae: 0.0420
# Epoch 44/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4982e-04 - mae: 0.0149 - val_loss: 0.0028 - val_mae: 0.0419
# Epoch 45/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5473e-04 - mae: 0.0151 - val_loss: 0.0028 - val_mae: 0.0414
# Epoch 46/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3374e-04 - mae: 0.0143 - val_loss: 0.0028 - val_mae: 0.0410
# Epoch 47/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1918e-04 - mae: 0.0142 - val_loss: 0.0027 - val_mae: 0.0404
# Epoch 48/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0074e-04 - mae: 0.0137 - val_loss: 0.0027 - val_mae: 0.0406
# Epoch 49/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0175e-04 - mae: 0.0137 - val_loss: 0.0026 - val_mae: 0.0403
# Epoch 50/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6799e-04 - mae: 0.0129 - val_loss: 0.0026 - val_mae: 0.0397
# Epoch 51/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7462e-04 - mae: 0.0132 - val_loss: 0.0026 - val_mae: 0.0401
# Epoch 52/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6349e-04 - mae: 0.0130 - val_loss: 0.0026 - val_mae: 0.0397
# Epoch 53/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7332e-04 - mae: 0.0130 - val_loss: 0.0025 - val_mae: 0.0390
# Epoch 54/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3530e-04 - mae: 0.0121 - val_loss: 0.0025 - val_mae: 0.0390
# Epoch 55/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3295e-04 - mae: 0.0119 - val_loss: 0.0024 - val_mae: 0.0385
# Epoch 56/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2552e-04 - mae: 0.0119 - val_loss: 0.0024 - val_mae: 0.0384
# Epoch 57/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9394e-04 - mae: 0.0111 - val_loss: 0.0024 - val_mae: 0.0384
# Epoch 58/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0689e-04 - mae: 0.0114 - val_loss: 0.0024 - val_mae: 0.0381
# Epoch 59/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9735e-04 - mae: 0.0111 - val_loss: 0.0023 - val_mae: 0.0376
# Epoch 60/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.8482e-04 - mae: 0.0108 - val_loss: 0.0023 - val_mae: 0.0376
# Epoch 61/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7412e-04 - mae: 0.0103 - val_loss: 0.0023 - val_mae: 0.0375
# Epoch 62/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.7245e-04 - mae: 0.0104 - val_loss: 0.0023 - val_mae: 0.0373
# Epoch 63/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.6608e-04 - mae: 0.0103 - val_loss: 0.0022 - val_mae: 0.0373
# Epoch 64/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6689e-04 - mae: 0.0102 - val_loss: 0.0022 - val_mae: 0.0367
# Epoch 65/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5239e-04 - mae: 0.0099 - val_loss: 0.0022 - val_mae: 0.0371
# Epoch 66/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4511e-04 - mae: 0.0096 - val_loss: 0.0022 - val_mae: 0.0364
# Epoch 67/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3348e-04 - mae: 0.0091 - val_loss: 0.0021 - val_mae: 0.0363
# Epoch 68/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4995e-04 - mae: 0.0098 - val_loss: 0.0021 - val_mae: 0.0364
# Epoch 69/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3408e-04 - mae: 0.0091 - val_loss: 0.0021 - val_mae: 0.0360
# Epoch 70/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2545e-04 - mae: 0.0089 - val_loss: 0.0021 - val_mae: 0.0358
# Epoch 71/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0881e-04 - mae: 0.0083 - val_loss: 0.0021 - val_mae: 0.0359
# Epoch 72/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3889e-04 - mae: 0.0095 - val_loss: 0.0021 - val_mae: 0.0358
# Epoch 73/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2242e-04 - mae: 0.0088 - val_loss: 0.0020 - val_mae: 0.0354
# Epoch 74/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1771e-04 - mae: 0.0086 - val_loss: 0.0020 - val_mae: 0.0354
# Epoch 75/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1844e-04 - mae: 0.0087 - val_loss: 0.0020 - val_mae: 0.0351
# Epoch 76/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1980e-04 - mae: 0.0086 - val_loss: 0.0020 - val_mae: 0.0349
# Epoch 77/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.9133e-05 - mae: 0.0079 - val_loss: 0.0019 - val_mae: 0.0344
# Epoch 78/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.6239e-05 - mae: 0.0079 - val_loss: 0.0019 - val_mae: 0.0345
# Epoch 79/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.7687e-05 - mae: 0.0074 - val_loss: 0.0019 - val_mae: 0.0347
# Epoch 80/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.4839e-05 - mae: 0.0078 - val_loss: 0.0019 - val_mae: 0.0343
# Epoch 81/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.8305e-05 - mae: 0.0075 - val_loss: 0.0018 - val_mae: 0.0340
# Epoch 82/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.0896e-05 - mae: 0.0071 - val_loss: 0.0018 - val_mae: 0.0336
# Epoch 83/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.5630e-05 - mae: 0.0073 - val_loss: 0.0018 - val_mae: 0.0338
# Epoch 84/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.7586e-05 - mae: 0.0071 - val_loss: 0.0018 - val_mae: 0.0336
# Epoch 85/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.7857e-05 - mae: 0.0069 - val_loss: 0.0018 - val_mae: 0.0335
# Epoch 86/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.0923e-05 - mae: 0.0067 - val_loss: 0.0018 - val_mae: 0.0335
# Epoch 87/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.8382e-05 - mae: 0.0065 - val_loss: 0.0018 - val_mae: 0.0335
# Epoch 88/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.5170e-05 - mae: 0.0069 - val_loss: 0.0018 - val_mae: 0.0333
# Epoch 89/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.5196e-05 - mae: 0.0067 - val_loss: 0.0018 - val_mae: 0.0332
# Epoch 90/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.5262e-05 - mae: 0.0064 - val_loss: 0.0017 - val_mae: 0.0327
# Epoch 91/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.4252e-05 - mae: 0.0063 - val_loss: 0.0018 - val_mae: 0.0329
# Epoch 92/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.8101e-05 - mae: 0.0065 - val_loss: 0.0017 - val_mae: 0.0326
# Epoch 93/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.8327e-05 - mae: 0.0061 - val_loss: 0.0017 - val_mae: 0.0328
# Epoch 94/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.5099e-05 - mae: 0.0063 - val_loss: 0.0017 - val_mae: 0.0325
# Epoch 95/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.4223e-05 - mae: 0.0058 - val_loss: 0.0017 - val_mae: 0.0321
# Epoch 96/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8897e-05 - mae: 0.0055 - val_loss: 0.0016 - val_mae: 0.0319
# Epoch 97/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3845e-05 - mae: 0.0059 - val_loss: 0.0017 - val_mae: 0.0328
# Epoch 98/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.5195e-05 - mae: 0.0059 - val_loss: 0.0016 - val_mae: 0.0319
# Epoch 99/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9527e-05 - mae: 0.0055 - val_loss: 0.0016 - val_mae: 0.0317
# Epoch 100/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5721e-05 - mae: 0.0054 - val_loss: 0.0016 - val_mae: 0.0319
# Direct ANN Test MSE: 0.0013107472332194448
# Direct ANN Test MAE (0–1): 0.02867545746266842
# Direct ANN Test MAE in score points: 2.867545746266842
# Direct ANN Epochs actually run: 100

# %% [markdown]
# Training & Validation Curves (fuzzy+ann)

# %%
plt.figure(figsize=(8,5))
plt.plot(history_fuzzy.history["loss"], label="Training Loss")
plt.plot(history_fuzzy.history["val_loss"], label="Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("MSE Loss")
plt.title("Fuzzy+ANN Training vs Validation Loss")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Actual vs Predicted (fuzzy+ann)

# %%
# Fuzzy+ANN Predictions
X_all_fuzzy = df_nn_fuzzy[feature_cols_with_fuzzy].values
X_all_fuzzy_scaled = scaler_fuzzy.transform(X_all_fuzzy)
y_pred_fuzzy_ann = model_fuzzy.predict(X_all_fuzzy_scaled, verbose=0).ravel() * 100

y_actual = df_fuzzy["Lifestyle_Score"].values

plt.figure(figsize=(6,6))
plt.scatter(y_actual, y_pred_fuzzy_ann, alpha=0.4)
plt.plot([0,100], [0,100], linestyle="--")
plt.xlabel("Actual Lifestyle Score")
plt.ylabel("Fuzzy+ANN Predicted Score")
plt.title("Actual vs Predicted (Fuzzy+ANN)")
plt.grid(True)
plt.show()

# %%
# Direct ANN Predictions
X_all_direct = df_nn[feature_cols].values
X_all_direct_scaled = scaler_direct.transform(X_all_direct)
y_pred_direct = model_direct.predict(X_all_direct_scaled, verbose=0).ravel() * 100

# Fuzzy Scores
fuzzy_scores = df["Fuzzy_Lifestyle_Score"].values

# Hybrid Average Predictions
y_pred_hybrid_avg = (fuzzy_scores + y_pred_direct) / 2

y_actual_avg = df["Lifestyle_Score"].values

plt.figure(figsize=(6,6))
plt.scatter(y_actual_avg, y_pred_hybrid_avg, alpha=0.4)
plt.plot([0,100], [0,100], linestyle="--")
plt.xlabel("Actual Lifestyle Score")
plt.ylabel("Hybrid Avg Predicted Score")
plt.title("Actual vs Predicted (Fuzzy–ANN Average)")
plt.grid(True)
plt.show()

# %% [markdown]
# Hybrid Prediction (Fuzzy + NN)

# %%
def hybrid_avg_predict(row_index):
    row = df.iloc[row_index]

    # ---------- Fuzzy Prediction ----------
    fuzzy_score, explanation = compute_fuzzy_score_and_explanation(row)

    # ---------- Direct ANN Prediction ----------
    x_vec = df_nn.iloc[[row_index]][feature_cols].values
    x_scaled = scaler_direct.transform(x_vec)

    nn_pred_norm = model_direct.predict(x_scaled, verbose=0)[0, 0]
    nn_score = float(nn_pred_norm * 100.0)

    # ---------- Hybrid Averaging ----------
    hybrid_score = (fuzzy_score + nn_score) / 2

    return fuzzy_score, nn_score, hybrid_score, explanation


# 🔹 Test on 5 samples
for i in range(5):
    fs, ns, hs, exp = hybrid_avg_predict(i)
    print(f"\nSample {i}")
    print(f"Fuzzy Score   : {fs:.2f}")
    print(f"NN Score      : {ns:.2f}")
    print(f"Hybrid Avg    : {hs:.2f}")
    print("Explanation  :", exp)
# Out:
# Sample 0
# Fuzzy Score   : 17.50
# NN Score      : 14.72
# Hybrid Avg    : 16.11
# Explanation  : Low score factors: low water intake, high stress, gastric problem
#
# Sample 1
# Fuzzy Score   : 14.09
# NN Score      : 7.31
# Hybrid Avg    : 10.70
# Explanation  : Low score factors: short sleep, low physical activity, low water intake, high stress, gastric problem
#
# Sample 2
# Fuzzy Score   : 17.50
# NN Score      : -0.07
# Hybrid Avg    : 8.72
# Explanation  : Low score factors: short dinner–sleep gap, high BMI (obesity), low physical activity, high stress, gastric problem
#
# Sample 3
# Fuzzy Score   : 14.09
# NN Score      : 19.25
# Hybrid Avg    : 16.67
# Explanation  : Low score factors: high stress, bilirubin issue, gastric problem
#
# Sample 4
# Fuzzy Score   : 19.02
# NN Score      : -0.54
# Hybrid Avg    : 9.24
# Explanation  : Low score factors: high BMI (obesity), unhealthy / fast food pattern, low physical activity, high stress, gastric problem

# %% [markdown]
# FUZZY+ANN vs HYBRID AVERAGE

# %%
plt.figure(figsize=(7,5))
plt.scatter(y_actual[:300], y_pred_fuzzy_ann[:300], label="Fuzzy+ANN", alpha=0.5)
plt.scatter(y_actual_avg[:300], y_pred_hybrid_avg[:300], label="Hybrid Average", alpha=0.5)
plt.xlabel("Actual Lifestyle Score")
plt.ylabel("Predicted Score")
plt.title("Prediction Comparison: Fuzzy+ANN vs Hybrid Average")
plt.legend()
plt.grid(True)
plt.show()
